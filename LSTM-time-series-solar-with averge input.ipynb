# %%
#data parameters
data_path = 'KNYITHAC52.csv'
test_ratio = 0.1
windows = 6
avg_windows = 10
target_id = 9

#model parameters
lstm_dim = 128
fc_dim = 128

#training parameters
training_state = True
learning_rate=1e-3
dropout = 0.1
batch_size = 256
num_epoch = 1000

#visualization para
test_show_num = 1000

#path para
best_model_LSTM = 'LSTM.h5'

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
plt.style.use('seaborn')
#tensorflow==2.4.0 keras==2.4.3 python==3.7.10

#plot
def myPlot(array, name):
    plt.figure(figsize=(10,5))
    plt.plot(array)
    plt.title(name,fontsize='20') 
    plt.show()
    print('\n')

#minmaxscaler
def myScaler(data, target):
    mm_x= MinMaxScaler()
    mm_y= MinMaxScaler()
    data = mm_x.fit_transform(data)
    label = mm_y.fit_transform(np.reshape(target, (-1, 1)))  
    return  data, label, mm_y

def dataGenerator(data, label, test_ratio, windows, avg_windows):
    data = np.array(data)
    cut = round(test_ratio* data.shape[0])
    lstm_input = []
    lstm_input2 = []
    lstm_output = []
    if avg_windows>windows:
        for i in range(len(data)-avg_windows):
            lstm_input.append(data[i+(avg_windows-windows):i+avg_windows,:])
            lstm_input2.append(data[i:i+avg_windows,:])           
            lstm_output.append(data[i+avg_windows,target_id])
    else:
        for i in range(len(data)-windows):
            lstm_input.append(data[i:i+windows,:])
            lstm_input2.append(data[i+(windows-avg_windows):i+windows,:])           
            lstm_output.append(data[i+windows,target_id])        
    lstm_input=np.array(lstm_input)
    lstm_input2=np.array(lstm_input2)
    lstm_input2 = lstm_input2.mean(axis=-1)
    lstm_output=np.array(lstm_output)  
    x_train,x2_train,y_train = lstm_input[:-cut,:,:],lstm_input2[:-cut,:],lstm_output[:-cut:]
    x_test,x2_test,y_test = lstm_input[-cut:,:,:],lstm_input2[-cut:,:],lstm_output[-cut:]
    print('x_train.shape',x_train.shape)
    print('x2_train.shape',x2_train.shape)
    print('y_train.shape',y_train.shape)
    print('x_test.shape',x_test.shape)
    print('x2_test.shape',x2_test.shape)
    print('y_test.shape',y_test.shape)
    return x_train, x2_train, x_test, y_train, x2_test, y_test

#read data
data = pd.read_csv(data_path, header=0, index_col=0)
data = data.iloc[:,1:]
data = pd.get_dummies(data)
print(data)
print(data.describe())
target = data.iloc[:,target_id].values

#plot y
myPlot(target, 'tem')

#scaler
data, label, mm_y = myScaler(data, target)

#generate data
x_train, x2_train, x_test, y_train, x2_test, y_test = dataGenerator(data, label, test_ratio, windows, avg_windows)
# Out:
#             Temperature_C  Dew_Point_C  Humidity_%  Speed_kmh  Gust_kmh  \
# Date
# 1/1/2021             0.00        -5.44          67        0.0      0.00
# 1/1/2021             0.00        -5.67          66        0.0      0.00
# 1/1/2021             0.00        -5.78          65        0.0      0.00
# 1/1/2021             0.00        -5.89          64        0.0      0.00
# 1/1/2021             0.00        -6.22          63        0.0      0.00
# ...                   ...          ...         ...        ...       ...
# 12/31/2021           3.89         3.67          98        0.0      0.00
# 12/31/2021           4.44         4.17          98        0.0      0.00
# 12/31/2021           5.06         4.72          98        0.0      0.16
# 12/31/2021           5.72         5.33          97        0.0      0.00
# 12/31/2021           6.33         5.94          97        0.0      0.00
#
#             Pressure_hPa  Precip_Rate_mm  Precip_Accum_mm  UV  Solar_w/m2  \
# Date
# 1/1/2021         1028.45             0.0             0.00   0         8.6
# 1/1/2021         1028.45             0.0             0.00   0         8.6
# 1/1/2021         1028.78             0.0             0.00   0         8.6
# 1/1/2021         1028.45             0.0             0.00   0         8.6
# 1/1/2021         1028.45             0.0             0.00   0         8.6
# ...                  ...             ...              ...  ..         ...
# 12/31/2021       1008.81             0.0             0.25   0         0.0
# 12/31/2021       1008.81             0.0             0.25   0         0.0
# 12/31/2021       1008.47             0.0             0.25   0         0.0
# 12/31/2021       1008.47             0.0             0.25   0         0.0
# 12/31/2021       1008.47             0.0             0.25   0         0.0
#
#             ...  Wind_NW  Wind_North  Wind_SE  Wind_SSE  Wind_SSW  Wind_SW  \
# Date        ...
# 1/1/2021    ...        0           0        1         0         0        0
# 1/1/2021    ...        0           0        0         1         0        0
# 1/1/2021    ...        0           0        0         0         0        0
# 1/1/2021    ...        0           0        0         0         0        0
# 1/1/2021    ...        0           0        0         1         0        0
# ...         ...      ...         ...      ...       ...       ...      ...
# 12/31/2021  ...        0           0        0         1         0        0
# 12/31/2021  ...        0           0        0         1         0        0
# 12/31/2021  ...        0           0        0         0         0        1
# 12/31/2021  ...        0           0        0         1         0        0
# 12/31/2021  ...        0           0        0         1         0        0
#
#             Wind_South  Wind_WNW  Wind_WSW  Wind_West
# Date
# 1/1/2021             0         0         0          0
# 1/1/2021             0         0         0          0
# 1/1/2021             1         0         0          0
# 1/1/2021             0         0         0          0
# 1/1/2021             0         0         0          0
# ...                ...       ...       ...        ...
# 12/31/2021           0         0         0          0
# 12/31/2021           0         0         0          0
# 12/31/2021           0         0         0          0
# 12/31/2021           0         0         0          0
# 12/31/2021           0         0         0          0
#
# [100391 rows x 26 columns]
#        Temperature_C    Dew_Point_C     Humidity_%      Speed_kmh  \
# count  100391.000000  100391.000000  100391.000000  100391.000000
# mean       10.387294       5.215847      72.850684       0.496406
# std        10.401623      11.446680      21.361761       1.085073
# min       -17.780000     -17.780000      11.000000       0.000000
# 25%         1.220000      -4.610000      56.000000       0.000000
# 50%        10.720000       6.170000      74.000000       0.000000
# 75%        19.280000      15.390000      94.000000       0.480000
# max        35.220000      26.610000      99.000000      15.290000
#
#             Gust_kmh   Pressure_hPa  Precip_Rate_mm  Precip_Accum_mm  \
# count  100391.000000  100391.000000   100391.000000    100391.000000
# mean        1.143549    1015.591126        0.190337         1.550204
# std         1.945282       6.524607        1.583870         5.377534
# min         0.000000     992.890000        0.000000         0.000000
# 25%         0.000000    1011.180000        0.000000         0.000000
# 50%         0.000000    1015.920000        0.000000         0.000000
# 75%         1.610000    1019.980000        0.000000         0.250000
# max        22.370000    1035.220000       91.690000        81.530000
#
#                   UV     Solar_w/m2  ...        Wind_NW     Wind_North  \
# count  100391.000000  100391.000000  ...  100391.000000  100391.000000
# mean        0.136486      66.258251  ...       0.013567       0.021227
# std         0.903535     124.424285  ...       0.115685       0.144141
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.000000       0.000000  ...       0.000000       0.000000
# 50%         0.000000       4.800000  ...       0.000000       0.000000
# 75%         0.000000      67.800000  ...       0.000000       0.000000
# max         9.000000     708.800000  ...       1.000000       1.000000
#
#              Wind_SE       Wind_SSE       Wind_SSW        Wind_SW  \
# count  100391.000000  100391.000000  100391.000000  100391.000000
# mean        0.057236       0.191182       0.091233       0.088882
# std         0.232295       0.393234       0.287942       0.284575
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#           Wind_South       Wind_WNW       Wind_WSW      Wind_West
# count  100391.000000  100391.000000  100391.000000  100391.000000
# mean        0.235479       0.014165       0.047803       0.026098
# std         0.424300       0.118170       0.213350       0.159427
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 26 columns]
# x_train.shape (90342, 6, 26)
# x2_train.shape (90342, 10)
# y_train.shape (90342,)
# x_test.shape (10039, 6, 26)
# x2_test.shape (10039, 10)
# y_test.shape (10039,)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input,LSTM,Dropout,Dense,Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop

def lstm_model():
    inputs = Input(shape=x_train.shape[1:])
    inputs2 = Input(shape=x2_train.shape[1:])
    
    lstm = LSTM(units=lstm_dim, return_sequences=False)(inputs)
    lstm = Dropout(dropout)(lstm)
    dense = Dense(fc_dim, activation="relu", use_bias=True)(lstm)
    
    dense2 = Dense(fc_dim, activation="relu", use_bias=True)(inputs2)
    
    outputs = Dense(1, activation="relu", use_bias=True)(Concatenate(axis=1)([dense, dense2]))
    
    model = Model(inputs=[inputs, inputs2], outputs=outputs)
    print(model.summary())
    model.compile(optimizer=RMSprop(learning_rate=1e-4), loss='mse',metrics=['accuracy'])
    return model

def myTrain(myModel, training_state, Path):
    es_patience = 10
    es = keras.callbacks.EarlyStopping(monitor='val_loss', patience=es_patience)
    cp = keras.callbacks.ModelCheckpoint(filepath = Path, monitor='val_loss', save_best_only=True)
    if training_state==True:
        history = myModel.fit(x= [x_train, x2_train],
                            y= y_train,
                            batch_size=batch_size,
                            epochs=num_epoch,
                            verbose=1,
                            callbacks=[es, cp],
                            validation_split=0.1)
        myLossPlot(history)
    myModel.load_weights(Path) 
    return myModel

def myLossPlot(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(loss))
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Val Loss')
    plt.legend(loc='upper right')
    plt.title('Train and Val Loss')
    plt.show()

myModel = lstm_model()
myModel = myTrain(myModel, training_state, best_model_LSTM)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 6, 26)]      0           []
#
#  lstm (LSTM)                    (None, 128)          79360       ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['lstm[0][0]']
#
#  input_2 (InputLayer)           [(None, 10)]         0           []
#
#  dense (Dense)                  (None, 128)          16512       ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 128)          1408        ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 256)          0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            257         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 97,537
# Trainable params: 97,537
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/1000
# 318/318 [==============================] - 12s 31ms/step - loss: 0.0076 - accuracy: 0.4198 - val_loss: 6.7707e-04 - val_accuracy: 0.5754
# Epoch 2/1000
# 318/318 [==============================] - 9s 28ms/step - loss: 0.0035 - accuracy: 0.4198 - val_loss: 6.1530e-04 - val_accuracy: 0.5754
# Epoch 3/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0032 - accuracy: 0.4198 - val_loss: 6.4155e-04 - val_accuracy: 0.5754
# Epoch 4/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0030 - accuracy: 0.4198 - val_loss: 5.8711e-04 - val_accuracy: 0.5754
# Epoch 5/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0028 - accuracy: 0.4199 - val_loss: 5.3294e-04 - val_accuracy: 0.5754
# Epoch 6/1000
# 318/318 [==============================] - 9s 28ms/step - loss: 0.0027 - accuracy: 0.4199 - val_loss: 5.2063e-04 - val_accuracy: 0.5754
# Epoch 7/1000
# 318/318 [==============================] - 9s 28ms/step - loss: 0.0026 - accuracy: 0.4198 - val_loss: 5.9052e-04 - val_accuracy: 0.5754
# Epoch 8/1000
# 318/318 [==============================] - 10s 31ms/step - loss: 0.0025 - accuracy: 0.4199 - val_loss: 5.0657e-04 - val_accuracy: 0.5754
# Epoch 9/1000
# 318/318 [==============================] - 10s 31ms/step - loss: 0.0025 - accuracy: 0.4199 - val_loss: 4.8671e-04 - val_accuracy: 0.5754
# Epoch 10/1000
# 318/318 [==============================] - 10s 30ms/step - loss: 0.0024 - accuracy: 0.4199 - val_loss: 5.5159e-04 - val_accuracy: 0.5754
# Epoch 11/1000
# 318/318 [==============================] - 10s 30ms/step - loss: 0.0024 - accuracy: 0.4199 - val_loss: 4.8043e-04 - val_accuracy: 0.5754
# Epoch 12/1000
# 318/318 [==============================] - 9s 29ms/step - loss: 0.0024 - accuracy: 0.4199 - val_loss: 5.0583e-04 - val_accuracy: 0.5754
# Epoch 13/1000
# 318/318 [==============================] - 10s 32ms/step - loss: 0.0023 - accuracy: 0.4199 - val_loss: 4.6065e-04 - val_accuracy: 0.5754
# Epoch 14/1000
# 318/318 [==============================] - 9s 30ms/step - loss: 0.0023 - accuracy: 0.4198 - val_loss: 4.5608e-04 - val_accuracy: 0.5754
# Epoch 15/1000
# 318/318 [==============================] - 10s 31ms/step - loss: 0.0023 - accuracy: 0.4199 - val_loss: 4.6049e-04 - val_accuracy: 0.5754
# Epoch 16/1000
# 318/318 [==============================] - 9s 29ms/step - loss: 0.0023 - accuracy: 0.4199 - val_loss: 4.7094e-04 - val_accuracy: 0.5754
# Epoch 17/1000
# 318/318 [==============================] - 8s 27ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.5205e-04 - val_accuracy: 0.5754
# Epoch 18/1000
# 318/318 [==============================] - 9s 28ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.5543e-04 - val_accuracy: 0.5754
# Epoch 19/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.5845e-04 - val_accuracy: 0.5754
# Epoch 20/1000
# 318/318 [==============================] - 9s 27ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.4322e-04 - val_accuracy: 0.5754
# Epoch 21/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.6949e-04 - val_accuracy: 0.5754
# Epoch 22/1000
# 318/318 [==============================] - 9s 27ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.3159e-04 - val_accuracy: 0.5754
# Epoch 23/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.4224e-04 - val_accuracy: 0.5754
# Epoch 24/1000
# 318/318 [==============================] - 9s 27ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.4520e-04 - val_accuracy: 0.5754
# Epoch 25/1000
# 318/318 [==============================] - 9s 27ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.3325e-04 - val_accuracy: 0.5754
# Epoch 26/1000
# 318/318 [==============================] - 9s 28ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.5165e-04 - val_accuracy: 0.5754
# Epoch 27/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0022 - accuracy: 0.4199 - val_loss: 4.7044e-04 - val_accuracy: 0.5754
# Epoch 28/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.5153e-04 - val_accuracy: 0.5754
# Epoch 29/1000
# 318/318 [==============================] - 9s 28ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.6895e-04 - val_accuracy: 0.5754
# Epoch 30/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.4825e-04 - val_accuracy: 0.5754
# Epoch 31/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.3322e-04 - val_accuracy: 0.5754
# Epoch 32/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.2169e-04 - val_accuracy: 0.5754
# Epoch 33/1000
# 318/318 [==============================] - 8s 27ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.3598e-04 - val_accuracy: 0.5754
# Epoch 34/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.2622e-04 - val_accuracy: 0.5754
# Epoch 35/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.3271e-04 - val_accuracy: 0.5754
# Epoch 36/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.4228e-04 - val_accuracy: 0.5754
# Epoch 37/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.5954e-04 - val_accuracy: 0.5754
# Epoch 38/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.3719e-04 - val_accuracy: 0.5754
# Epoch 39/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.3080e-04 - val_accuracy: 0.5754
# Epoch 40/1000
# 318/318 [==============================] - 7s 23ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.7326e-04 - val_accuracy: 0.5754
# Epoch 41/1000
# 318/318 [==============================] - 7s 23ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.1991e-04 - val_accuracy: 0.5754
# Epoch 42/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.2135e-04 - val_accuracy: 0.5754
# Epoch 43/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.2317e-04 - val_accuracy: 0.5754
# Epoch 44/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.2659e-04 - val_accuracy: 0.5754
# Epoch 45/1000
# 318/318 [==============================] - 7s 23ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.1368e-04 - val_accuracy: 0.5754
# Epoch 46/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.5970e-04 - val_accuracy: 0.5754
# Epoch 47/1000
# 318/318 [==============================] - 7s 22ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.1691e-04 - val_accuracy: 0.5754
# Epoch 48/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.2005e-04 - val_accuracy: 0.5754
# Epoch 49/1000
# 318/318 [==============================] - 7s 22ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.1604e-04 - val_accuracy: 0.5754
# Epoch 50/1000
# 318/318 [==============================] - 8s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.1036e-04 - val_accuracy: 0.5754
# Epoch 51/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.3627e-04 - val_accuracy: 0.5754
# Epoch 52/1000
# 318/318 [==============================] - 9s 27ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.3273e-04 - val_accuracy: 0.5754
# Epoch 53/1000
# 318/318 [==============================] - 9s 27ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.1966e-04 - val_accuracy: 0.5754
# Epoch 54/1000
# 318/318 [==============================] - 9s 27ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.2927e-04 - val_accuracy: 0.5754
# Epoch 55/1000
# 318/318 [==============================] - 9s 27ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.2471e-04 - val_accuracy: 0.5754
# Epoch 56/1000
# 318/318 [==============================] - 9s 29ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.2414e-04 - val_accuracy: 0.5754
# Epoch 57/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.2438e-04 - val_accuracy: 0.5754
# Epoch 58/1000
# 318/318 [==============================] - 9s 28ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.1694e-04 - val_accuracy: 0.5754
# Epoch 59/1000
# 318/318 [==============================] - 7s 24ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.0695e-04 - val_accuracy: 0.5754
# Epoch 60/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0021 - accuracy: 0.4199 - val_loss: 4.0590e-04 - val_accuracy: 0.5754
# Epoch 61/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.6419e-04 - val_accuracy: 0.5754
# Epoch 62/1000
# 318/318 [==============================] - 8s 26ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.4458e-04 - val_accuracy: 0.5754
# Epoch 63/1000
# 318/318 [==============================] - 7s 23ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.1693e-04 - val_accuracy: 0.5754
# Epoch 64/1000
# 318/318 [==============================] - 7s 24ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.1690e-04 - val_accuracy: 0.5754
# Epoch 65/1000
# 318/318 [==============================] - 7s 23ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.1814e-04 - val_accuracy: 0.5754
# Epoch 66/1000
# 318/318 [==============================] - 9s 28ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.1384e-04 - val_accuracy: 0.5754
# Epoch 67/1000
# 318/318 [==============================] - 7s 23ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.2567e-04 - val_accuracy: 0.5754
# Epoch 68/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.4340e-04 - val_accuracy: 0.5754
# Epoch 69/1000
# 318/318 [==============================] - 7s 23ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.0605e-04 - val_accuracy: 0.5754
# Epoch 70/1000
# 318/318 [==============================] - 8s 25ms/step - loss: 0.0020 - accuracy: 0.4199 - val_loss: 4.1538e-04 - val_accuracy: 0.5754

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from math import sqrt
        
def myInverseScaler(pred, mm_y):
    pred=np.reshape(pred, (-1,1))  
    pred= mm_y.inverse_transform(pred)
    pred=pred[:,0]
    return pred

def mape(y_true, y_pred):    
    n = len(y_true)
    mape = sum(np.abs((y_true - y_pred)/y_true))/n*100
    return mape

def myResultPlot(pred, real, trainToken, show_num):
    plt.figure(figsize=(10,5))
    plt.plot(real[-show_num:])
    plt.plot(pred[-show_num:])
    plt.legend(('real', 'predict'),fontsize='15')
    plt.title("%s Data"%(trainToken),fontsize='15')
    plt.show()
    print('\n')

    plot_begin,plot_end=min(min(pred),min(real)),max(max(pred),max(real))
    plot_x=np.linspace(plot_begin,plot_end,10)
    plt.figure(figsize=(5,5))
    plt.plot(plot_x,plot_x)
    plt.plot(real,pred,'o')
    plt.title("%s Data"%trainToken,fontsize='15')
    plt.show()

def myResultMetric(pred, real, trainToken):
    print('%s MAE/RMSE/MAPE/R^2'%(trainToken))
    print(mean_absolute_error(real, pred))
    print(np.sqrt(mean_squared_error(real, pred) ))
    print(mape(real, pred) )
    print(r2_score(real, pred))   

def myResultSave(pred, real, trainToken, modelToken):
    pred_data = np.vstack([real, pred])
    pred_df = pd.DataFrame(pred_data).T
    pred_df.columns = ['real', 'pred']
    pred_df.to_csv('Result_%s_%s.csv'%(modelToken ,trainToken))    

def myResult(pred, real, trainToken, modelToken, show_num):
    myResultPlot(pred, real, trainToken, show_num)
    myResultMetric(pred, real, trainToken)
    myResultSave(pred, real, trainToken, modelToken)

y_pred = myModel.predict([x_test, x2_test])
y_pred = myInverseScaler(y_pred, mm_y)
y_test = myInverseScaler(y_test, mm_y)
myResult(pred = y_pred,
     real = y_test,
     trainToken='Test',
     modelToken='LSTM',
     show_num=test_show_num
    )
# Out:
# Test MAE/RMSE/MAPE/R^2
# 3.0465244029892866
# 8.872068669414867
# nan
# 0.9167144710700226
# C:\Users\xurong\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\xurong\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in true_divide
