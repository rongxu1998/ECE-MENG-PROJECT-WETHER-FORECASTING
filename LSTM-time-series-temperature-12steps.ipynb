# %%
#data parameters
data_path = 'KNYITHAC52.csv'
test_ratio = 0.1
windows = 6
pred_step = 12
avg_windows = 10
target_id = 0

#model parameters
lstm_dim = 128
fc_dim = 128

#training parameters
training_state = True
learning_rate=1e-3
dropout = 0.1
batch_size = 256
num_epoch = 1000

#visualization para
test_show_num = 1000

#path para
best_model_LSTM = 'LSTM.h5'

# %% [markdown]
# # Data Processing

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
plt.style.use('seaborn')
#tensorflow==2.4.0 keras==2.4.3 python==3.7.10

#plot
def myPlot(array, name):
    plt.figure(figsize=(10,5))
    plt.plot(array)
    plt.title(name,fontsize='20') 
    plt.show()
    print('\n')

#minmaxscaler
def myScaler(data, target):
    mm_x= MinMaxScaler()
    mm_y= MinMaxScaler()
    data = mm_x.fit_transform(data)
    label = mm_y.fit_transform(np.reshape(target, (-1, 1)))  
    return  data, label, mm_y

def dataGenerator(data, label, test_ratio, windows, avg_windows,pred_step):
    data = np.array(data)
    cut = round(test_ratio* data.shape[0])
    lstm_input = []
    lstm_input2 = []
    lstm_output = []
    if avg_windows>windows:
        for i in range(len(data)-avg_windows-pred_step):
            lstm_input.append(data[i+(avg_windows-windows):i+avg_windows,:])
            lstm_input2.append(data[i:i+avg_windows,:])           
            lstm_output.append(data[i+avg_windows:i+avg_windows+pred_step:,target_id])
    else:
        for i in range(len(data)-windows-pred_step):
            lstm_input.append(data[i:i+windows,:])
            lstm_input2.append(data[i+(windows-avg_windows):i+windows,:])           
            lstm_output.append(data[i+windows:i+windows+pred_step,target_id])        
    lstm_input=np.array(lstm_input)
    lstm_input2=np.array(lstm_input2)
    lstm_input2 = lstm_input2.mean(axis=-1)
    lstm_output=np.array(lstm_output)  
    x_train,x2_train,y_train = lstm_input[:-cut,:,:],lstm_input2[:-cut,:],lstm_output[:-cut:]
    x_test,x2_test,y_test = lstm_input[-cut:,:,:],lstm_input2[-cut:,:],lstm_output[-cut:]
    print('x_train.shape',x_train.shape)
    print('x2_train.shape',x2_train.shape)
    print('y_train.shape',y_train.shape)
    print('x_test.shape',x_test.shape)
    print('x2_test.shape',x2_test.shape)
    print('y_test.shape',y_test.shape)
    return x_train, x2_train, x_test, y_train, x2_test, y_test

#read data
data = pd.read_csv(data_path, header=0, index_col=0)
data = data.iloc[:,1:]
data = pd.get_dummies(data)
print(data)
print(data.describe())
target = data.iloc[:,target_id].values

#plot y
myPlot(target, 'tem')

#scaler
data, label, mm_y = myScaler(data, target)

#generate data
x_train, x2_train, x_test, y_train, x2_test, y_test = dataGenerator(data,
                       label, test_ratio, windows, avg_windows,pred_step)
# Out:
#             Temperature_C  Dew_Point_C  Humidity_%  Speed_kmh  Gust_kmh  \
# Date
# 1/1/2021             0.00        -5.44          67        0.0      0.00
# 1/1/2021             0.00        -5.67          66        0.0      0.00
# 1/1/2021             0.00        -5.78          65        0.0      0.00
# 1/1/2021             0.00        -5.89          64        0.0      0.00
# 1/1/2021             0.00        -6.22          63        0.0      0.00
# ...                   ...          ...         ...        ...       ...
# 12/31/2021           3.89         3.67          98        0.0      0.00
# 12/31/2021           4.44         4.17          98        0.0      0.00
# 12/31/2021           5.06         4.72          98        0.0      0.16
# 12/31/2021           5.72         5.33          97        0.0      0.00
# 12/31/2021           6.33         5.94          97        0.0      0.00
#
#             Pressure_hPa  Precip_Rate_mm  Precip_Accum_mm  UV  Solar_w/m2  \
# Date
# 1/1/2021         1028.45             0.0             0.00   0         8.6
# 1/1/2021         1028.45             0.0             0.00   0         8.6
# 1/1/2021         1028.78             0.0             0.00   0         8.6
# 1/1/2021         1028.45             0.0             0.00   0         8.6
# 1/1/2021         1028.45             0.0             0.00   0         8.6
# ...                  ...             ...              ...  ..         ...
# 12/31/2021       1008.81             0.0             0.25   0         0.0
# 12/31/2021       1008.81             0.0             0.25   0         0.0
# 12/31/2021       1008.47             0.0             0.25   0         0.0
# 12/31/2021       1008.47             0.0             0.25   0         0.0
# 12/31/2021       1008.47             0.0             0.25   0         0.0
#
#             ...  Wind_NW  Wind_North  Wind_SE  Wind_SSE  Wind_SSW  Wind_SW  \
# Date        ...
# 1/1/2021    ...        0           0        1         0         0        0
# 1/1/2021    ...        0           0        0         1         0        0
# 1/1/2021    ...        0           0        0         0         0        0
# 1/1/2021    ...        0           0        0         0         0        0
# 1/1/2021    ...        0           0        0         1         0        0
# ...         ...      ...         ...      ...       ...       ...      ...
# 12/31/2021  ...        0           0        0         1         0        0
# 12/31/2021  ...        0           0        0         1         0        0
# 12/31/2021  ...        0           0        0         0         0        1
# 12/31/2021  ...        0           0        0         1         0        0
# 12/31/2021  ...        0           0        0         1         0        0
#
#             Wind_South  Wind_WNW  Wind_WSW  Wind_West
# Date
# 1/1/2021             0         0         0          0
# 1/1/2021             0         0         0          0
# 1/1/2021             1         0         0          0
# 1/1/2021             0         0         0          0
# 1/1/2021             0         0         0          0
# ...                ...       ...       ...        ...
# 12/31/2021           0         0         0          0
# 12/31/2021           0         0         0          0
# 12/31/2021           0         0         0          0
# 12/31/2021           0         0         0          0
# 12/31/2021           0         0         0          0
#
# [100391 rows x 26 columns]
#        Temperature_C    Dew_Point_C     Humidity_%      Speed_kmh  \
# count  100391.000000  100391.000000  100391.000000  100391.000000
# mean       10.387294       5.215847      72.850684       0.496406
# std        10.401623      11.446680      21.361761       1.085073
# min       -17.780000     -17.780000      11.000000       0.000000
# 25%         1.220000      -4.610000      56.000000       0.000000
# 50%        10.720000       6.170000      74.000000       0.000000
# 75%        19.280000      15.390000      94.000000       0.480000
# max        35.220000      26.610000      99.000000      15.290000
#
#             Gust_kmh   Pressure_hPa  Precip_Rate_mm  Precip_Accum_mm  \
# count  100391.000000  100391.000000   100391.000000    100391.000000
# mean        1.143549    1015.591126        0.190337         1.550204
# std         1.945282       6.524607        1.583870         5.377534
# min         0.000000     992.890000        0.000000         0.000000
# 25%         0.000000    1011.180000        0.000000         0.000000
# 50%         0.000000    1015.920000        0.000000         0.000000
# 75%         1.610000    1019.980000        0.000000         0.250000
# max        22.370000    1035.220000       91.690000        81.530000
#
#                   UV     Solar_w/m2  ...        Wind_NW     Wind_North  \
# count  100391.000000  100391.000000  ...  100391.000000  100391.000000
# mean        0.136486      66.258251  ...       0.013567       0.021227
# std         0.903535     124.424285  ...       0.115685       0.144141
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.000000       0.000000  ...       0.000000       0.000000
# 50%         0.000000       4.800000  ...       0.000000       0.000000
# 75%         0.000000      67.800000  ...       0.000000       0.000000
# max         9.000000     708.800000  ...       1.000000       1.000000
#
#              Wind_SE       Wind_SSE       Wind_SSW        Wind_SW  \
# count  100391.000000  100391.000000  100391.000000  100391.000000
# mean        0.057236       0.191182       0.091233       0.088882
# std         0.232295       0.393234       0.287942       0.284575
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#           Wind_South       Wind_WNW       Wind_WSW      Wind_West
# count  100391.000000  100391.000000  100391.000000  100391.000000
# mean        0.235479       0.014165       0.047803       0.026098
# std         0.424300       0.118170       0.213350       0.159427
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 26 columns]
# x_train.shape (90330, 6, 26)
# x2_train.shape (90330, 10)
# y_train.shape (90330, 12)
# x_test.shape (10039, 6, 26)
# x2_test.shape (10039, 10)
# y_test.shape (10039, 12)

# %% [markdown]
# # LSTM

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input,LSTM,Dropout,Dense,Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop

def lstm_model():
    inputs = Input(shape=x_train.shape[1:])
    inputs2 = Input(shape=x2_train.shape[1:])
    
    lstm = LSTM(units=lstm_dim, return_sequences=False)(inputs)
    lstm = Dropout(dropout)(lstm)
    dense = Dense(fc_dim, activation="relu", use_bias=True)(lstm)
    
    dense2 = Dense(fc_dim, activation="relu", use_bias=True)(inputs2)
    
    outputs = Dense(pred_step, activation="relu", use_bias=True)(Concatenate(axis=1)([dense, dense2]))
    
    model = Model(inputs=[inputs, inputs2], outputs=outputs)
    print(model.summary())
    model.compile(optimizer=RMSprop(learning_rate=1e-4), loss='mse',metrics=['accuracy'])
    return model

def myTrain(myModel, training_state, Path):
    es_patience = 10
    es = keras.callbacks.EarlyStopping(monitor='val_loss', patience=es_patience)
    cp = keras.callbacks.ModelCheckpoint(filepath = Path, monitor='val_loss', save_best_only=True)
    if training_state==True:
        history = myModel.fit(x= [x_train, x2_train],
                            y= y_train,
                            batch_size=batch_size,
                            epochs=num_epoch,
                            verbose=1,
                            callbacks=[es, cp],
                            validation_split=0.1)
        myLossPlot(history)
    myModel.load_weights(Path) 
    return myModel

def myLossPlot(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(loss))
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Val Loss')
    plt.legend(loc='upper right')
    plt.title('Train and Val Loss')
    plt.show()

myModel = lstm_model()
myModel = myTrain(myModel, training_state, best_model_LSTM)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6, 26)]      0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 128)          79360       input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           lstm[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          16512       dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          1408        input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 256)          0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 12)           3084        concatenate[0][0]
# ==================================================================================================
# Total params: 100,364
# Trainable params: 100,364
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/1000
# 318/318 [==============================] - 7s 18ms/step - loss: 0.1440 - accuracy: 0.0315 - val_loss: 0.0178 - val_accuracy: 0.3765
# Epoch 2/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 0.0313 - accuracy: 0.1537 - val_loss: 0.0171 - val_accuracy: 0.1139
# Epoch 3/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 0.0275 - accuracy: 0.1124 - val_loss: 4.1989e-04 - val_accuracy: 0.0854
# Epoch 4/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 9.9502e-04 - accuracy: 0.0875 - val_loss: 3.6773e-04 - val_accuracy: 0.1663
# Epoch 5/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 7.8641e-04 - accuracy: 0.1021 - val_loss: 3.1331e-04 - val_accuracy: 0.1848
# Epoch 6/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 6.8113e-04 - accuracy: 0.1080 - val_loss: 3.4420e-04 - val_accuracy: 0.2344
# Epoch 7/1000
# 318/318 [==============================] - 5s 17ms/step - loss: 6.1174e-04 - accuracy: 0.1149 - val_loss: 3.5801e-04 - val_accuracy: 0.2035
# Epoch 8/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 5.6346e-04 - accuracy: 0.1199 - val_loss: 2.8108e-04 - val_accuracy: 0.2305
# Epoch 9/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 5.1845e-04 - accuracy: 0.1224 - val_loss: 3.0666e-04 - val_accuracy: 0.2486
# Epoch 10/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 4.8057e-04 - accuracy: 0.1259 - val_loss: 2.7571e-04 - val_accuracy: 0.2409
# Epoch 11/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 4.6205e-04 - accuracy: 0.1299 - val_loss: 2.8570e-04 - val_accuracy: 0.2503
# Epoch 12/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 4.3744e-04 - accuracy: 0.1320 - val_loss: 2.6507e-04 - val_accuracy: 0.2608
# Epoch 13/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 4.1653e-04 - accuracy: 0.1381 - val_loss: 3.3773e-04 - val_accuracy: 0.2729
# Epoch 14/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 4.0295e-04 - accuracy: 0.1419 - val_loss: 3.2462e-04 - val_accuracy: 0.2765
# Epoch 15/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.9419e-04 - accuracy: 0.1467 - val_loss: 2.6061e-04 - val_accuracy: 0.2639
# Epoch 16/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.7864e-04 - accuracy: 0.1521 - val_loss: 2.7264e-04 - val_accuracy: 0.2617
# Epoch 17/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.6943e-04 - accuracy: 0.1555 - val_loss: 2.6186e-04 - val_accuracy: 0.2802
# Epoch 18/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.5591e-04 - accuracy: 0.1622 - val_loss: 4.4240e-04 - val_accuracy: 0.2708
# Epoch 19/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.4939e-04 - accuracy: 0.1618 - val_loss: 2.4706e-04 - val_accuracy: 0.2851
# Epoch 20/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 3.3649e-04 - accuracy: 0.1645 - val_loss: 3.8747e-04 - val_accuracy: 0.2908
# Epoch 21/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 3.3286e-04 - accuracy: 0.1722 - val_loss: 2.4104e-04 - val_accuracy: 0.2929
# Epoch 22/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.2244e-04 - accuracy: 0.1758 - val_loss: 2.7863e-04 - val_accuracy: 0.2786
# Epoch 23/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.2143e-04 - accuracy: 0.1757 - val_loss: 2.7032e-04 - val_accuracy: 0.3288
# Epoch 24/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.1568e-04 - accuracy: 0.1815 - val_loss: 2.2384e-04 - val_accuracy: 0.3136
# Epoch 25/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 3.0542e-04 - accuracy: 0.1912 - val_loss: 2.3260e-04 - val_accuracy: 0.3161
# Epoch 26/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.9717e-04 - accuracy: 0.1934 - val_loss: 2.1554e-04 - val_accuracy: 0.3186
# Epoch 27/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.9270e-04 - accuracy: 0.1970 - val_loss: 2.3112e-04 - val_accuracy: 0.3226
# Epoch 28/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.9025e-04 - accuracy: 0.2054 - val_loss: 2.5296e-04 - val_accuracy: 0.3364
# Epoch 29/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.8340e-04 - accuracy: 0.2112 - val_loss: 2.4098e-04 - val_accuracy: 0.3261
# Epoch 30/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.8079e-04 - accuracy: 0.2145 - val_loss: 2.0874e-04 - val_accuracy: 0.3440
# Epoch 31/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.7173e-04 - accuracy: 0.2212 - val_loss: 2.0184e-04 - val_accuracy: 0.3498
# Epoch 32/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.7181e-04 - accuracy: 0.2248 - val_loss: 2.1509e-04 - val_accuracy: 0.3358
# Epoch 33/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.6496e-04 - accuracy: 0.2318 - val_loss: 2.0966e-04 - val_accuracy: 0.3584
# Epoch 34/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.6323e-04 - accuracy: 0.2406 - val_loss: 1.9871e-04 - val_accuracy: 0.3487
# Epoch 35/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.5635e-04 - accuracy: 0.2397 - val_loss: 1.8939e-04 - val_accuracy: 0.3494
# Epoch 36/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.5320e-04 - accuracy: 0.2505 - val_loss: 2.0812e-04 - val_accuracy: 0.3453
# Epoch 37/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.4560e-04 - accuracy: 0.2524 - val_loss: 2.7611e-04 - val_accuracy: 0.3589
# Epoch 38/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.4567e-04 - accuracy: 0.2573 - val_loss: 1.8562e-04 - val_accuracy: 0.3544
# Epoch 39/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.4270e-04 - accuracy: 0.2633 - val_loss: 1.9950e-04 - val_accuracy: 0.3654
# Epoch 40/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.3603e-04 - accuracy: 0.2684 - val_loss: 1.7417e-04 - val_accuracy: 0.3370
# Epoch 41/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.3427e-04 - accuracy: 0.2717 - val_loss: 2.1681e-04 - val_accuracy: 0.3834
# Epoch 42/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.3086e-04 - accuracy: 0.2749 - val_loss: 2.4136e-04 - val_accuracy: 0.3703
# Epoch 43/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.2687e-04 - accuracy: 0.2834 - val_loss: 2.2148e-04 - val_accuracy: 0.3706
# Epoch 44/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.3051e-04 - accuracy: 0.2892 - val_loss: 1.7985e-04 - val_accuracy: 0.3640
# Epoch 45/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 2.2320e-04 - accuracy: 0.2889 - val_loss: 1.6132e-04 - val_accuracy: 0.3705
# Epoch 46/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 2.2513e-04 - accuracy: 0.2959 - val_loss: 1.6731e-04 - val_accuracy: 0.3879
# Epoch 47/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.1729e-04 - accuracy: 0.2976 - val_loss: 1.7169e-04 - val_accuracy: 0.3616
# Epoch 48/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.1765e-04 - accuracy: 0.3006 - val_loss: 1.8813e-04 - val_accuracy: 0.3744
# Epoch 49/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.1549e-04 - accuracy: 0.3044 - val_loss: 1.7185e-04 - val_accuracy: 0.3699
# Epoch 50/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.0860e-04 - accuracy: 0.3082 - val_loss: 1.7127e-04 - val_accuracy: 0.3767
# Epoch 51/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.0794e-04 - accuracy: 0.3108 - val_loss: 1.8511e-04 - val_accuracy: 0.3931
# Epoch 52/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.0824e-04 - accuracy: 0.3139 - val_loss: 1.7672e-04 - val_accuracy: 0.3730
# Epoch 53/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.0558e-04 - accuracy: 0.3203 - val_loss: 1.6010e-04 - val_accuracy: 0.3658
# Epoch 54/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 2.0689e-04 - accuracy: 0.3212 - val_loss: 1.5771e-04 - val_accuracy: 0.3675
# Epoch 55/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.0148e-04 - accuracy: 0.3206 - val_loss: 1.8015e-04 - val_accuracy: 0.3915
# Epoch 56/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 2.0937e-04 - accuracy: 0.3253 - val_loss: 2.0723e-04 - val_accuracy: 0.3898
# Epoch 57/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.9757e-04 - accuracy: 0.3295 - val_loss: 2.1040e-04 - val_accuracy: 0.3913
# Epoch 58/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.9859e-04 - accuracy: 0.3322 - val_loss: 1.5370e-04 - val_accuracy: 0.3798
# Epoch 59/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.9325e-04 - accuracy: 0.3404 - val_loss: 1.6059e-04 - val_accuracy: 0.3507
# Epoch 60/1000
# 318/318 [==============================] - 5s 14ms/step - loss: 1.9324e-04 - accuracy: 0.3377 - val_loss: 2.0382e-04 - val_accuracy: 0.3761
# Epoch 61/1000
# 318/318 [==============================] - 5s 14ms/step - loss: 1.9150e-04 - accuracy: 0.3406 - val_loss: 1.4733e-04 - val_accuracy: 0.3267
# Epoch 62/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.8581e-04 - accuracy: 0.3466 - val_loss: 1.4257e-04 - val_accuracy: 0.3632
# Epoch 63/1000
# 318/318 [==============================] - 5s 14ms/step - loss: 1.8411e-04 - accuracy: 0.3478 - val_loss: 1.4493e-04 - val_accuracy: 0.3669
# Epoch 64/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.9077e-04 - accuracy: 0.3447 - val_loss: 1.4317e-04 - val_accuracy: 0.3746
# Epoch 65/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.8626e-04 - accuracy: 0.3481 - val_loss: 1.6751e-04 - val_accuracy: 0.3763
# Epoch 66/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.8349e-04 - accuracy: 0.3465 - val_loss: 1.4183e-04 - val_accuracy: 0.3308
# Epoch 67/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 1.8115e-04 - accuracy: 0.3467 - val_loss: 1.4000e-04 - val_accuracy: 0.3427
# Epoch 68/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.8584e-04 - accuracy: 0.3589 - val_loss: 1.4945e-04 - val_accuracy: 0.3715
# Epoch 69/1000
# 318/318 [==============================] - 5s 17ms/step - loss: 1.8207e-04 - accuracy: 0.3621 - val_loss: 1.4588e-04 - val_accuracy: 0.3662
# Epoch 70/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 1.8265e-04 - accuracy: 0.3622 - val_loss: 1.7221e-04 - val_accuracy: 0.3834
# Epoch 71/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 1.7927e-04 - accuracy: 0.3647 - val_loss: 1.3576e-04 - val_accuracy: 0.3615
# Epoch 72/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.7497e-04 - accuracy: 0.3640 - val_loss: 1.3884e-04 - val_accuracy: 0.3520
# Epoch 73/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.7643e-04 - accuracy: 0.3662 - val_loss: 1.5908e-04 - val_accuracy: 0.3698
# Epoch 74/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.7355e-04 - accuracy: 0.3682 - val_loss: 1.4339e-04 - val_accuracy: 0.3631
# Epoch 75/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.7494e-04 - accuracy: 0.3695 - val_loss: 1.3692e-04 - val_accuracy: 0.3554
# Epoch 76/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6963e-04 - accuracy: 0.3737 - val_loss: 1.5837e-04 - val_accuracy: 0.3360
# Epoch 77/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 1.7363e-04 - accuracy: 0.3724 - val_loss: 1.2855e-04 - val_accuracy: 0.3591
# Epoch 78/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 1.7185e-04 - accuracy: 0.3809 - val_loss: 1.6734e-04 - val_accuracy: 0.3599
# Epoch 79/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6976e-04 - accuracy: 0.3744 - val_loss: 1.5737e-04 - val_accuracy: 0.4097
# Epoch 80/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6862e-04 - accuracy: 0.3805 - val_loss: 1.9222e-04 - val_accuracy: 0.4161
# Epoch 81/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6617e-04 - accuracy: 0.3787 - val_loss: 1.2574e-04 - val_accuracy: 0.3321
# Epoch 82/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6838e-04 - accuracy: 0.3795 - val_loss: 1.4083e-04 - val_accuracy: 0.3661
# Epoch 83/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6891e-04 - accuracy: 0.3845 - val_loss: 1.2556e-04 - val_accuracy: 0.3432
# Epoch 84/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6238e-04 - accuracy: 0.3846 - val_loss: 1.4470e-04 - val_accuracy: 0.3468
# Epoch 85/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6297e-04 - accuracy: 0.3861 - val_loss: 1.2358e-04 - val_accuracy: 0.3622
# Epoch 86/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6235e-04 - accuracy: 0.3910 - val_loss: 1.4049e-04 - val_accuracy: 0.3864
# Epoch 87/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5973e-04 - accuracy: 0.3877 - val_loss: 1.3759e-04 - val_accuracy: 0.3834
# Epoch 88/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5777e-04 - accuracy: 0.3971 - val_loss: 1.2465e-04 - val_accuracy: 0.3745
# Epoch 89/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6061e-04 - accuracy: 0.3914 - val_loss: 1.2321e-04 - val_accuracy: 0.3608
# Epoch 90/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5985e-04 - accuracy: 0.3974 - val_loss: 1.2304e-04 - val_accuracy: 0.3766
# Epoch 91/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5331e-04 - accuracy: 0.3935 - val_loss: 1.3451e-04 - val_accuracy: 0.3857
# Epoch 92/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.6033e-04 - accuracy: 0.3987 - val_loss: 1.2418e-04 - val_accuracy: 0.3328
# Epoch 93/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5605e-04 - accuracy: 0.3947 - val_loss: 1.4563e-04 - val_accuracy: 0.3866
# Epoch 94/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5517e-04 - accuracy: 0.3996 - val_loss: 1.2252e-04 - val_accuracy: 0.3825
# Epoch 95/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 1.6069e-04 - accuracy: 0.4026 - val_loss: 1.4306e-04 - val_accuracy: 0.3779
# Epoch 96/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5336e-04 - accuracy: 0.4061 - val_loss: 1.1915e-04 - val_accuracy: 0.3506
# Epoch 97/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5421e-04 - accuracy: 0.4024 - val_loss: 1.4273e-04 - val_accuracy: 0.3760
# Epoch 98/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5597e-04 - accuracy: 0.4019 - val_loss: 1.1986e-04 - val_accuracy: 0.3757
# Epoch 99/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5264e-04 - accuracy: 0.4033 - val_loss: 1.1785e-04 - val_accuracy: 0.3909
# Epoch 100/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5329e-04 - accuracy: 0.4076 - val_loss: 1.1988e-04 - val_accuracy: 0.3813
# Epoch 101/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5387e-04 - accuracy: 0.4122 - val_loss: 1.2362e-04 - val_accuracy: 0.3843
# Epoch 102/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5140e-04 - accuracy: 0.4103 - val_loss: 1.3061e-04 - val_accuracy: 0.4250
# Epoch 103/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4945e-04 - accuracy: 0.4143 - val_loss: 1.1805e-04 - val_accuracy: 0.3673
# Epoch 104/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5149e-04 - accuracy: 0.4131 - val_loss: 1.1985e-04 - val_accuracy: 0.3646
# Epoch 105/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4586e-04 - accuracy: 0.4152 - val_loss: 1.1878e-04 - val_accuracy: 0.4034
# Epoch 106/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.5409e-04 - accuracy: 0.4157 - val_loss: 1.2372e-04 - val_accuracy: 0.3767
# Epoch 107/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4993e-04 - accuracy: 0.4166 - val_loss: 1.1749e-04 - val_accuracy: 0.3957
# Epoch 108/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4517e-04 - accuracy: 0.4162 - val_loss: 1.3843e-04 - val_accuracy: 0.4078
# Epoch 109/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4707e-04 - accuracy: 0.4156 - val_loss: 1.2983e-04 - val_accuracy: 0.3617
# Epoch 110/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4565e-04 - accuracy: 0.4199 - val_loss: 1.1852e-04 - val_accuracy: 0.3980
# Epoch 111/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4395e-04 - accuracy: 0.4211 - val_loss: 1.1267e-04 - val_accuracy: 0.4085
# Epoch 112/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4863e-04 - accuracy: 0.4225 - val_loss: 1.3852e-04 - val_accuracy: 0.4087
# Epoch 113/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4833e-04 - accuracy: 0.4223 - val_loss: 1.1146e-04 - val_accuracy: 0.3802
# Epoch 114/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4715e-04 - accuracy: 0.4227 - val_loss: 1.1472e-04 - val_accuracy: 0.4391
# Epoch 115/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4729e-04 - accuracy: 0.4254 - val_loss: 1.1452e-04 - val_accuracy: 0.3981
# Epoch 116/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4111e-04 - accuracy: 0.4236 - val_loss: 1.0864e-04 - val_accuracy: 0.4053
# Epoch 117/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4208e-04 - accuracy: 0.4263 - val_loss: 1.0523e-04 - val_accuracy: 0.3982
# Epoch 118/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4453e-04 - accuracy: 0.4276 - val_loss: 1.1242e-04 - val_accuracy: 0.4239
# Epoch 119/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4781e-04 - accuracy: 0.4350 - val_loss: 1.1820e-04 - val_accuracy: 0.3981
# Epoch 120/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 1.3930e-04 - accuracy: 0.4316 - val_loss: 1.1955e-04 - val_accuracy: 0.4006
# Epoch 121/1000
# 318/318 [==============================] - 5s 16ms/step - loss: 1.4166e-04 - accuracy: 0.4299 - val_loss: 1.1118e-04 - val_accuracy: 0.4017
# Epoch 122/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4043e-04 - accuracy: 0.4353 - val_loss: 1.4889e-04 - val_accuracy: 0.4243
# Epoch 123/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4358e-04 - accuracy: 0.4346 - val_loss: 1.7135e-04 - val_accuracy: 0.4370
# Epoch 124/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.3890e-04 - accuracy: 0.4347 - val_loss: 1.7563e-04 - val_accuracy: 0.4632
# Epoch 125/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.4206e-04 - accuracy: 0.4351 - val_loss: 1.2732e-04 - val_accuracy: 0.4176
# Epoch 126/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.3903e-04 - accuracy: 0.4372 - val_loss: 1.2298e-04 - val_accuracy: 0.4209
# Epoch 127/1000
# 318/318 [==============================] - 5s 15ms/step - loss: 1.3646e-04 - accuracy: 0.4351 - val_loss: 1.8153e-04 - val_accuracy: 0.4350

# %% [markdown]
# # Test

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from math import sqrt
        
def myInverseScaler(pred, mm_y):
    pred=np.reshape(pred, (-1,1))  
    pred= mm_y.inverse_transform(pred)
    pred=pred[:,0]
    return pred

def mape(y_true, y_pred):    
    n = len(y_true)
    mape = sum(np.abs((y_true - y_pred)/y_true))/n*100
    return mape

def myResultPlot(pred, real, trainToken):
    plt.figure(figsize=(10,5))
    plt.plot(real)
    plt.plot(pred)
    plt.legend(('real', 'predict'),fontsize='15')
    plt.title("%s Data"%(trainToken),fontsize='15')
    plt.show()
    print('\n')

    plot_begin,plot_end=min(min(pred),min(real)),max(max(pred),max(real))
    plot_x=np.linspace(plot_begin,plot_end,10)
    plt.figure(figsize=(5,5))
    plt.plot(plot_x,plot_x)
    plt.plot(real,pred,'o')
    plt.title("%s Data"%trainToken,fontsize='15')
    plt.show()

def myResult(pred_list, real_list, trainToken, modelToken, mm_y):
    print('==============%s %s Result==============='%(modelToken, trainToken))
    record = []
    count = 0
    for real, pred in zip(real_list, pred_list):
        count+=1
        real = mm_y.inverse_transform(np.reshape(real, (-1, 1)))
        pred = mm_y.inverse_transform(np.reshape(pred, (-1, 1)))
        if count==3999:
            myResultPlot(pred, real, trainToken)
        record2 = []
        record2.append(mean_absolute_error(real, pred))
        record2.append(np.sqrt(mean_squared_error(real, pred)))
        record2.append(None)#mape(real, pred)
        record2.append(None)#r2_score(real, pred)
        record.append(record2)
    result = pd.DataFrame(record)  
    result.columns = ['MAE','RMSE','MAPE','R^2']
    print(result.mean())      
    print('==============%s %s Result==============='%(modelToken, trainToken))
    
y_pred = myModel.predict([x_test, x2_test])
myResult(pred_list = y_pred,
     real_list = y_test,
     trainToken='Test',
     modelToken='LSTM_LT',
    mm_y = mm_y
    )
# Out:
# ==============LSTM_LT Test Result===============
# MAE     0.324909
# RMSE    0.368164
# MAPE         NaN
# R^2          NaN
# dtype: float64
# ==============LSTM_LT Test Result===============
